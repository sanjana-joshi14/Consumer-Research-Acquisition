# %%
pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

from google.colab import drive

# %%
from google_play_scraper import app, Sort, reviews_all

ind_reviews = reviews_all(
    'App_name',
    sleep_milliseconds=0,
    lang='en',
    country='in',
    sort=Sort.NEWEST,
    filter_score_with=None
)

# %%
ind_reviews
# Out:
# [{'reviewId': '99a53d43-09cc-4690-8b3c-cfe2502cb205',
#   'userName': 'Kirtizala Zalakirti',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtc1MbjEEMCx6Mo10Ya6fFIawWzVX9Hxs1u4VGWJRs8m1w=mo',
#   'content': 'Zala KIRTISINH',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 6, 2, 29, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'ec0ad500-4430-4c42-9900-6541851915dc',
#   'userName': 'sudhakar chandha',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdslR4JfWEjnSpjvN3pqYG2JdwRN1rRvUr77uUSHnxa=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 17, 25, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'e6d945dc-262d-4a86-a18e-591250c5f22d',
#   'userName': 'Biswajit Mazumdar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQtiIAEmikFnwKnVkm2s8mHAc4G1jcSNX_VQ09HDakSCmw',
#   'content': "please upgrade your 3rd class app, Better than this, I will make this type of app. What's going on?",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 5, 17, 5, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '92d60372-9ff4-44bb-bc9d-6f67969b8244',
#   'userName': 'ronit kumar Singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQY25Uhz1Udp7MIl9rHVdF-c9iDmlJLSJxf9PXZrzxl7Zuc',
#   'content': "The mobile application UI is pathetic and it lacks to fulfil the customer needs on time, as being a user the services / functions are always down i.e. not working effectively. For instance, the Transfer window is totally waste, as we can't transfer money from Bandhan bank to other banks. Bandhan Bank, kindly work on your mobile application as your interface is not upgraded in today's time.!",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 17, 3, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '485139fa-bd1a-46d4-bc50-d8fb4422d0fb',
#   'userName': 'Trinath Ray',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSmz1sb0NfMZAEixTJJhfSRqL7Cbzim9Vywe8kVH_V4_8XG',
#   'content': 'Very disappointing experience. Need be completely change',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 16, 41, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '08792054-282a-4b83-9808-af73969a9355',
#   'userName': 'DrM a Gulrez',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT2MJ__HxZMp3VVXPd-E3i3XqUahKwUiKeD8lnRrgVXi9U',
#   'content': 'Very good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 16, 36, 28),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '31428540-1bf2-41c1-ab74-02b14d7aad59',
#   'userName': 'Pranabendra lal Dey',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRB4BrELv4IXozlf2QxdeHRWx4D_4xKZ2YCW69kW8XcV6I',
#   'content': 'Worst ever app I have ever experienced.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 16, 15, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'd72e7aa8-10a0-4cf2-bf2d-bb8a8cc4fb41',
#   'userName': 'bharat gupta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQyPbLC_c9gOg9H9NTrKbZOud2UOw9mQCkjTGvAe05bzRE',
#   'content': 'jab bhi open kro technical issue',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 15, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '290f42de-d96c-44cb-a0ef-d365e2df6de3',
#   'userName': 'Barun sar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtejvEqE26oG07V5gMJXd04YPEImlYRqA4TpXZK4IHHa=mo',
#   'content': 'It is not opened and all the time showing technical issue',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 15, 42, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '5568666e-10e9-4448-829b-f57c6c134aac',
#   'userName': 'Arjun hada',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfN0eTX_p7PAlCv-UrC7h2QuQGLAi92_dcN2mmsjziW=mo',
#   'content': 'Too much facing technical issues',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 14, 28, 36),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2022, 11, 28, 12, 30, 40),
#   'appVersion': '2.3.1'},
#  {'reviewId': '86399c84-18c0-456f-8ec4-67e7a5c1fb20',
#   'userName': 'Virat',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte7N-8t4VIIgafWs-E6H4hlHwKfjtQul6Z6yeFtLYVXbg=mo',
#   'content': 'Poor quality app',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 14, 12, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'bc10e535-2e17-434b-8794-6b39aec63629',
#   'userName': 'abhishek shukla',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTAOO4aFoeLB-_NLniapShJPAXIjAh_XdDBOoDT9PlDa5o',
#   'content': 'Irritate app hai.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 14, 8, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'a5371b00-ab6f-489f-bc6e-926f13525617',
#   'userName': 'Resab Pradhan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRxNSlz7R61fW0kOxz9GGqCKV5swz9grwXZU5i17TEPtVk',
#   'content': 'It was working fine but now it says that my number is not linked with the account.. is this a joke now whole of my acc seems at risk',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 13, 38, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '6f650705-5772-4822-b5d0-0aac10b49fdf',
#   'userName': 'Raj Kumar Mondal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtexGJWrsdX8FHUPEERGf6rUoXkrQ6hUquZBqHCYh1_KaA=mo',
#   'content': 'Asome',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 13, 18, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '315d4d1e-fdec-4787-a9de-ddbfe9061f51',
#   'userName': 'Rajjak Zamader',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTsYcepE5tYXDfQFN8gRzz8jt0NqX5BFHckRaAjYlBVT58',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 13, 13, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'b1498838-bdf8-4134-85a3-1738fc1a48fc',
#   'userName': 'Arnab Paul',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQdOTj9ZVlwFY1oLmZ8dethQO_q_52HGlG2xaHXK4lZAWc',
#   'content': 'Bad experience',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 11, 13, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '68d68da1-7d90-4b6c-a5d6-773a69e4adf8',
#   'userName': 'Karan Mandal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSHg9AekcUFClMOwK8SGOnrGa4Eh5oek94oSp7NrXLBu14',
#   'content': 'Slow as snail, does not function properly. It show invalid details at the same it opens after retrying and this process continues. I cant check my last transactions.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 7, 16, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'd7eb6960-8bb1-4b61-9bd3-41fe53dbb6bf',
#   'userName': 'Jai Kumar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcwkemrAqSfrmm-qkYE6GexQi6_e-Wdbnhoe1qieMcd=mo',
#   'content': 'Login fails most of the time',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 7, 14, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '52246162-2b63-4301-9e8e-38e5f1810eac',
#   'userName': 'Mohit Kumar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfCxgk2PYnDhbxtXJ7604S6tBDb_yeNbmydXf33bJNr=mo',
#   'content': 'App not working',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 5, 7, 9, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '6fb71499-65f5-4838-a7c9-fd6b7d32f613',
#   'userName': 'Fahad Tanveer',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtetUTe00aQFsSO0N6aaDNXm2s3a5vZtFZMNHnQ0w6-V=mo',
#   'content': 'Pathetic app. Worst banking mobile app in the country.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 6, 37, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '4203632b-6f15-442f-869b-79cb398d0756',
#   'userName': 'Samar Mahapatra',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQuP4kKGyhtNe9E046O9zoaWqKcYXJ37PhwAm7QnFb4bR6h',
#   'content': "Most faltu app..not working properly every time..after 8 years in banking sector they don't have a proper app for customer..they have lots of money for advertising but they don't have solution for the app.. thinking why I have open the account.not recommend.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 6, 10, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'afa70e04-8691-411e-8de2-2a5607205724',
#   'userName': 'Saipayan Dutta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTpyabdaJA0T3mgO9wqbG_vjx-HP6g-ptIZ0WoCYakF6G0',
#   'content': 'Good app by Bandhan Bank. All the Bandhan bank customers need to visit the nearest branch and activate both internet and mobile banking and register with the registered mobile no. with data connection in that SIM. The SIM has to be in the primary SIM slot for dual sim phones.',
#   'score': 5,
#   'thumbsUpCount': 43,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 4, 31, 23),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 45, 3),
#   'appVersion': '2.3.1'},
#  {'reviewId': '9a00b1eb-1525-4b63-8706-490f0194d453',
#   'userName': 'Kaamal Halder',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdkee2emj0cM5CCKFbfVogYStMbiJQHu9sdYNJ4STyv=mo',
#   'content': 'Poor signal,very slow does not work fast.',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 2, 42, 56),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 44, 15),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'b13072f3-c6fe-41d8-ad3c-a3aea22c0953',
#   'userName': 'Krishna Gupta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTKepDODVwA2OyHS34Cyvlho-OJsAYIr144J2TZ2yNXZU0',
#   'content': 'Good 👍',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 5, 2, 30, 1),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 41, 57),
#   'appVersion': '2.3.1'},
#  {'reviewId': '170e1cae-82b9-468e-8578-2663453b2eaf',
#   'userName': 'Parakram Singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQPZXd02w0ctj22R6XbkPX9KHiEHGpMYbIoTmLQvIM2KcA',
#   'content': "Trash app. Though my mobile number is registered with the bank, still this app is saying that my number isn't registered with bank. Trash bank and app.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 4, 20, 21, 54),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 41, 49),
#   'appVersion': None},
#  {'reviewId': '8115ecf5-8867-456d-8be9-4275c13e3900',
#   'userName': 'Rajen Prasad',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte9cjaC02j-MBbG6Nw07AK6Z3QDb17B6zP8m77bO4pp=mo',
#   'content': 'Bad experience',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 17, 32, 4),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 41, 28),
#   'appVersion': '2.3.1'},
#  {'reviewId': '5d6b4a48-574a-4a7a-8869-c4c813852b8a',
#   'userName': 'Avishikta Paul',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQLEzkAMrhgicAejXcH9PiO-y041joeVdOqMwqswZ98N2yJ',
#   'content': 'Poor user interface',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 17, 29, 23),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 40, 38),
#   'appVersion': '2.3.1'},
#  {'reviewId': '90264a3a-35b1-4e2b-8a09-235121ea82d6',
#   'userName': 'Ony G',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQBTroAYqu4iowqT-SYWa_0aVX7mRcOAKbGlECOX0KaKQ',
#   'content': 'App is not working',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 16, 56, 12),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 39, 49),
#   'appVersion': '2.3.1'},
#  {'reviewId': '596a90a2-bf30-4565-93e8-77032f49c522',
#   'userName': 'Anuj Sethi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfUrn6aBAsYEvA05D-uDeT1NHSTJbLZwVebPMsbotvG=mo',
#   'content': 'Gud services & gud staff behaviour gud bank',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 4, 14, 46, 13),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 35, 59),
#   'appVersion': None},
#  {'reviewId': '1a9ad119-fccd-4a83-b062-3ba874742270',
#   'userName': 'Akbar Ali',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTmjBkcuhDFE2-InrMFcdyTVG18tuuP4ShgYWC5DtpvYw',
#   'content': 'Mobile number Kam nahi hota hai',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 13, 9, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '37dfde1f-9f91-4692-af80-515e692a5acb',
#   'userName': 'Deba Prasad Tripathy',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSyvipqkAinYy1Djrc7JxWy08wCTTb_pU33RoSoV8IQFZk',
#   'content': "A pathetic app. Maximum time it won't work properly.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 13, 4, 6),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 5, 5, 35, 6),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'd1e0f841-093f-4b3b-a716-f7d696b33a43',
#   'userName': 'ArkoPravo ghosh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQiNby3YLsFw1MTdRtPib7_WJ6LlOlFcTmQ32zrkgQhy00',
#   'content': 'The app didnt open. Always showing Technical Issue. 3rd Class App.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 12, 33, 6),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 6, 38),
#   'appVersion': '2.3.1'},
#  {'reviewId': '58ea3a77-e3d6-43d3-98df-dd378486ebcc',
#   'userName': 'Surajit Show',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte9FMzx5P4AfOKce1WFZvSG0GFVviA8SN3XVGLh85BQ=mo',
#   'content': "I have used this app 5 years, suddenly I can't money transfer through IMPS . I reinstall the app but the app is not working, then I am going to branch of bandhan bank but they have not solution this problem.",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.1.9',
#   'at': datetime.datetime(2023, 9, 4, 11, 42, 42),
#   'replyContent': 'Thank you for your positive review. Hope you continue enjoying mBandhan, mobile banking app.',
#   'repliedAt': datetime.datetime(2021, 5, 31, 11, 48, 33),
#   'appVersion': '2.1.9'},
#  {'reviewId': '0e85d554-03f4-4beb-8a87-29870eaa068a',
#   'userName': 'Srittam Behera',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRS_fBG8o_R2i00TF6TkYQVqo2giN_Qgrcv_9sZKNVpOw',
#   'content': 'Super',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 4, 10, 32, 2),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 6, 8),
#   'appVersion': None},
#  {'reviewId': 'ac1bf5a6-a584-4ecf-9e2a-69a9390f14b2',
#   'userName': 'Varun Sharma',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQzLjP4ND2VC4uDT-_z_ApBm_uRyZozGKaSNCRW7hNsQpE',
#   'content': 'Worst app ever...such a big Bank and this sort of app...very disappointed',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 10, 6, 27),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 6, 49),
#   'appVersion': '2.3.1'},
#  {'reviewId': '554c2b5b-76dd-4ee8-ae05-184d09d5c13c',
#   'userName': 'Sonu Sktiwari121',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSM0s216fEkakIrgG0DlDW1FW1cM90V7iYuHG4nXwsdwRY1',
#   'content': 'ttz Fe Desh HQ BB BB fd free f fta i u ll xx Xx AA f fta xx aap s fte a Chh e www xx xxy f ur ch cc çtffse gg yy h hiise m gg hu',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 8, 44, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '146e7b37-5171-44ca-b8dd-c81c2c8828dd',
#   'userName': 'NIYAS M',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQlrMiuIGo_tKaw0bq1UdnfX02yzw5cZYCu_bn744caPg',
#   'content': 'Our bank, our account even current or savings not useful on emergency time',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 6, 38, 13),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 7, 10),
#   'appVersion': '2.3.1'},
#  {'reviewId': '8d52887c-5d8e-4e09-bf70-4db53c974130',
#   'userName': 'Rashid Rana',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQoyGihDh7JRjQyaFsHy3lgZpDpWyi-j3kBcHU3dg1hVA',
#   'content': 'Today tomach problem',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 5, 56, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': 'b1292a39-7f4c-4c84-bb28-817327e18086',
#   'userName': 'himanshu kumar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQO9JWPxSE3EkK1idIleMKChoT-npTH_DLC1PvH7DjUokC7',
#   'content': 'good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 4, 57, 18),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 52),
#   'appVersion': '2.3.1'},
#  {'reviewId': '6e659531-5f06-4d62-a445-f15fb4ad51bc',
#   'userName': 'Biplab Mandal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT36MSM3fo9yKQI9bppPwmrWsZfSBYbcfQx2fMOcLCPCS0',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 4, 45, 38),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 46),
#   'appVersion': '2.3.1'},
#  {'reviewId': '79a2a6db-4e1f-44ef-b053-367768694941',
#   'userName': 'Sushmita Baruah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQSzApnBEZ4ileoS3URkeKKSqE7-OtNYur61hdFTJnRI6I',
#   'content': 'The worst bank app in the history of mobile banking. In case of emergency transactions please avoid using this app. You will be highly disappointed.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 4, 3, 46, 24),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 7, 36),
#   'appVersion': '2.3.1'},
#  {'reviewId': '3c4fd087-287a-45fd-810c-591eb261de90',
#   'userName': 'SUJIT SAHA',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfDVlO6JOhY_aQJcKZqzbJQGQbyz4OMWJlzKT02vlto=mo',
#   'content': 'Nice app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 3, 16, 47, 24),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 39),
#   'appVersion': '2.3.1'},
#  {'reviewId': '6b19414e-86b4-46f8-b625-5671ac32f704',
#   'userName': 'mohit raj',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRziG4VJQxjdS11JBsajT6H2zrGtIHpdL2J0ZCxCUj8oA',
#   'content': 'Bad',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 3, 12, 29, 18),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 7, 44),
#   'appVersion': '2.3.1'},
#  {'reviewId': '17ff6744-477b-44c8-8c2c-8dd7fb9c014b',
#   'userName': 'Santosh khonde',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteSnNBktKR8VtbKmI-s-o_hI5irAJZG-6vJzBVawfg=mo',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 2, 11, 39, 53),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 33),
#   'appVersion': None},
#  {'reviewId': '6d25e11f-69e4-4566-87d9-8cd2ab23bb36',
#   'userName': 'Tarun Ghosh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTAXt4Y83sNSSn0ZQGbecLXi0BE0NAOJQymMoBDurSdxRA',
#   'content': 'Very bad and unprofessional activity.😡😡 FD cannot prematiore which opened online.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 2, 8, 17, 21),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 8, 16, 12, 44, 50),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'c899b5af-64fb-4136-b802-606d8b0c2af4',
#   'userName': 'Santosh Shinde',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRdbRxF1rFjxHB6NikCYsZTVM6wd9--_E0HB6vimMK60uY',
#   'content': 'I want to know how many days are required to get List of documents of current home loan..',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 9, 1, 18, 30, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '504832d2-2771-4c2a-a6cc-bcbc01f02a25',
#   'userName': 'santosh mondal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT6g_IXqUgbGSamgUIeHmpl_uyWbkx-ZoqEZ_KdmBavmR8',
#   'content': 'Excellent',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 9, 1, 6, 35, 56),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 26),
#   'appVersion': '2.3.1'},
#  {'reviewId': '9880bc38-3138-4e6a-9649-77a2fdeb205e',
#   'userName': 'Santosh Panja',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfaU3yUV91PVmd63ll0O_ooACy6GcQ-8pARoRBQVm2q=mo',
#   'content': 'Excellent service',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.0',
#   'at': datetime.datetime(2023, 9, 1, 3, 45, 33),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 20),
#   'appVersion': '2.3.0'},
#  {'reviewId': '17ed22ad-8fdc-4973-b770-bd32bc7a49a8',
#   'userName': 'ritesh prajapati',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRnikB34FF3fn65_ySKglsRe4OCsRXv1x9bEEC9zTN6CMg',
#   'content': 'Good',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 31, 18, 55, 59),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 15),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'bad34368-718e-4780-89e9-6794750641bc',
#   'userName': 'Sujith Ramdas',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMS029cevo4Z4LRk-DE2sT12Tzh3jBQNRuJq9yVTKzprYRo',
#   'content': 'Very basic.Definitely need an upgrade. Both mobile banking app as well as internet banking. Functionalities and features are very limited.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 30, 14, 30, 10),
#   'replyContent': 'Thank you for reviewing us. We have noted your feedback and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 5, 2),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'ebae6efa-25b6-495d-a3d0-0992280682e7',
#   'userName': 'Mahesh O',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQmjbAtgzDN6buvz1-earJ-weR-1u28zFIJhZwlydDEyPA',
#   'content': "Worst app can't open properly",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 30, 14, 5, 20),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 9, 4, 13, 4, 29),
#   'appVersion': '2.3.1'},
#  {'reviewId': '943959cf-8a15-4bd7-b41e-df7365a193a9',
#   'userName': 'Pappu Bhadra',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTUPHPNyAPZTXGyf3U8R4WqWMSfCwAt1w6h9qJMFk9vfp8',
#   'content': 'Bandhan Bank customer care support is good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 30, 8, 11, 19),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 30, 12, 9, 47),
#   'appVersion': '2.3.1'},
#  {'reviewId': '8c8933ce-513b-4607-8b87-a6332d6232ca',
#   'userName': 'PARIDHI SINGH',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdQEsw026Dw8aHi6TERnisa5HHFK5xrk-gy9Fl9_Gdo=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.0',
#   'at': datetime.datetime(2023, 8, 30, 5, 3, 17),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 30, 12, 9, 44),
#   'appVersion': '2.3.0'},
#  {'reviewId': 'bf584a72-7881-4f3e-b15d-ecc93ceb0338',
#   'userName': 'Ramkumar Rathore',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQXFf5c1J6w3yPX0d5G1DiVGxmT4XJenRdOpyh-j886714',
#   'content': 'Bahut badhiya app hai',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 29, 14, 0, 17),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 30, 12, 9, 41),
#   'appVersion': '2.3.1'},
#  {'reviewId': '603bd039-c116-4304-ab9f-cf2fa9f366a0',
#   'userName': 'YOUR TALENT',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTlWyKiImSaIESOWVtPdfgGvfGmKvugz92iOWFYlhHN_so',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 29, 7, 9, 11),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 41, 1),
#   'appVersion': '2.3.1'},
#  {'reviewId': '0d5e1fb4-5a04-4979-8f0c-9e89e1698bbe',
#   'userName': 'YOGESH KUMAR',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSc3EG7JZ2zDS6j9F6uWuWFh04debG4Dn5dYj8S_nwOgfk',
#   'content': 'Good apps',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 27, 11, 7, 49),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 40, 57),
#   'appVersion': '2.3.1'},
#  {'reviewId': '2ffbd6ac-e6e3-44b8-934a-b825e80cd6fd',
#   'userName': 'sayyad gouse basha',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTFZQU7azHteGEWFE0oPFuY7gd5vtsLXQAoxJYHt7_gPMg',
#   'content': 'One of the worest ul ever u guys really read customers comments',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 27, 10, 59, 52),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 40, 48),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'ccb6f8bd-a8e4-4978-a5f2-e8c2c40f1db8',
#   'userName': 'Rita Singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdaqNzuPuvqdlt4CG7bKAqRgVO3yRKTNz-MIaVF-XoE=mo',
#   'content': 'bogus app....gets logout within minutes',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 27, 10, 50, 29),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 40, 39),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'ff2e9e04-ff30-4378-9289-6b5319caf950',
#   'userName': 'Milon Haldar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMS1KrJbqvKAlyM0TAC_zo5emEf57OwjghRB5FZBJ2czQbo',
#   'content': 'Good app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 27, 8, 33, 6),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 40, 19),
#   'appVersion': '2.3.1'},
#  {'reviewId': 'd18cefe7-e950-480b-abb7-c2262be29909',
#   'userName': 'Kaishar Alam',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSp9DxhfcLQHS_lz74duVnRDpZd1xL8tBGtCiueDzmojg',
#   'content': 'So good',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 27, 4, 32, 49),
#   'replyContent': 'Thank you for reviewing us.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 39, 24),
#   'appVersion': '2.3.1'},
#  {'reviewId': '37924452-1a3b-404b-9756-a1dc3a43ef4f',
#   'userName': 'Singh rawa Ankit',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteaUFEmuFuXC-EyhjJR87rGaUrdiZVuuhJ-RbY3yyVL=mo',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 26, 17, 24, 46),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 39, 10),
#   'appVersion': '2.3.1'},
#  {'reviewId': '65e06a39-a30e-4b41-9864-db9944908c9b',
#   'userName': 'Anushree Ghosh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQGtzb4L_E-u_9pkZWK7cXsDqF3ZWcrOb2WQwODs9rJUoQ',
#   'content': 'Good 😊😊',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 26, 15, 48, 38),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 39, 3),
#   'appVersion': '2.3.1'},
#  {'reviewId': '60ed56a1-2058-4363-85c6-aec82a3926f9',
#   'userName': 'JAY DAS',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTnhr1i9a06zKc5ST82xFBP0L4iFLMxhZxYHkXYEzINiQ',
#   'content': 'এতো খারাপ মোবাইল ব্যাংকিং এপ্লিকেশন আমি দেখিনি ব্যাংক ভালো কিন্ত এই এপ্লিকেশন একদম মান্ধারতার আমলের। যেখানে দেশ ও সব ব্যাংকিং ব্যাবস্থা ডিজিটাল ও খুব সহজ হয়ে উঠেছে কিন্তু বন্ধন ব্যাংক কেন তার মোবাইল ব্যাংকিং এপ্লিকেশন টিকে উন্নত মানের করছে না ?? আমি একজন গ্রাহক হিসাবে খুবই দুঃখী। দ্রুত এই APP টিকে ভালো করুন।',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 8, 26, 6, 6, 6),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 38, 52),
#   'appVersion': None},
#  {'reviewId': '6c208e56-2126-4d4a-9101-e7094f5399a8',
#   'userName': 'P K PRASUN',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMS8Cu0OWHANrOCAjfNChwQFKm652ZRC2pX7OEPlRCh4J3fq',
#   'content': 'The bank grown up by sucking the blood of the poor.A lot of money has been looted from the poor.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 26, 4, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '8cdb378a-8e9a-473f-a930-942960bb43d3',
#   'userName': 'JYOTIRMAY BOSE',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte2OLhPNN4rg-xcF3VUlChhYS7jLD3JsPYpKK5-xMHZ=mo',
#   'content': 'Very good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.0',
#   'at': datetime.datetime(2023, 8, 24, 6, 6, 56),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 37, 18),
#   'appVersion': '2.3.0'},
#  {'reviewId': '7b8f8dce-337d-4ccb-9667-ec4ed6e6bdc9',
#   'userName': 'saumita chakrobortty',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRXW0CNb-TLmgUSxVyJTgSBas2nXNteEijzAQaMn88n2w',
#   'content': 'Worst Banking application.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 23, 17, 43, 17),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 37, 3),
#   'appVersion': '2.3.1'},
#  {'reviewId': '9784fab1-75b5-408d-9642-f96997dbeb31',
#   'userName': 'Ananta kumar Sahu',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcYIG7TkrkGCg1HWewaFStRamb-LP6nbIZIhQ0xng80=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 23, 14, 22, 1),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 36, 47),
#   'appVersion': '2.3.1'},
#  {'reviewId': '7f4139b4-1b06-4679-ab06-a06d193f6379',
#   'userName': 'Tarun Soni',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT_FPKVY5inSNwmHhccpQITA6Qy-ZyTIFg7sgJRfO1Odq4',
#   'content': "Useless application, even can't get a statement of your account, hell like expreance, damm it",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.0',
#   'at': datetime.datetime(2023, 8, 23, 6, 59, 41),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 36, 38),
#   'appVersion': '2.3.0'},
#  {'reviewId': 'f04e8977-e098-40ce-8ef5-79b2eaff411e',
#   'userName': 'Mustakim Ali',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRZlE71IddpJl2PqFS00CFlpJq9s5aJ7JazdXFJLIh8xK0',
#   'content': 'My',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 23, 6, 57, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.3.1'},
#  {'reviewId': '4a37d54c-bf2e-4a63-948e-a28461c3d0c1',
#   'userName': 'Satyam Agarwal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRr6y-T2soibijG9JnMzaS72YAWBeATtHboGnw0PoWkYJbN',
#   'content': 'App is same as branch poor performance',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.0',
#   'at': datetime.datetime(2023, 8, 23, 4, 26, 16),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 36, 21),
#   'appVersion': '2.3.0'},
#  {'reviewId': '9a0fcecd-626a-49bc-b3fb-1d9820d2d2c1',
#   'userName': 'Deepm Rajput',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdR9ZgaEKvCTQVQvcoNH-oRFngojIuiHWvYhp1iDe_d=mo',
#   'content': 'Super',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.0',
#   'at': datetime.datetime(2023, 8, 22, 16, 26, 37),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 34, 58),
#   'appVersion': '2.3.0'},
#  {'reviewId': 'd4748b17-cb6e-40d2-b263-5ea76e68f872',
#   'userName': 'Yogesh kumar Yadav',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQRlU3gcm3pmcgSuIHN4uJybj26isJdT2rSVNiqeyo54g',
#   'content': 'many times App not run smoothly and option not much more',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 22, 14, 19, 3),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 34, 51),
#   'appVersion': '2.3.1'},
#  {'reviewId': '5be449a1-e936-40a2-98b1-037848090bc1',
#   'userName': 'Sameer Rider',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQzzMBOuXgbuv82QWYlK6eO1y5U4zQ-QCbi7K7lLeON8A',
#   'content': "Cheap app I want pdf of my account statement but I can't see the option",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 22, 9, 8, 34),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 34, 20),
#   'appVersion': '2.3.1'},
#  {'reviewId': '4a1a7718-6688-4604-accf-9187007f963f',
#   'userName': 'Deepak Ingale',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQrdstpenZ28UxZIJ-cMR0NBadNahLQCOxbEmnahf5TEg',
#   'content': '3rd class app, 3rd class service.. 3rd class grievance solving process..',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 8, 22, 8, 44, 42),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 33, 57),
#   'appVersion': None},
#  {'reviewId': '1793e440-46ac-4769-933f-867e0d012eff',
#   'userName': 'Manish Jain',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT6QeXtCgqj1XoPBC9Fo7W6qI-ayELlnFuxEPmS7WMcC6E',
#   'content': "While making transfers we don't have search options, we need to scroll down entire list . Please work on this.",
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 8, 22, 4, 30, 44),
#   'replyContent': 'Thank you for reviewing us. We have noted your feedback and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 8, 29, 12, 33, 11),
#   'appVersion': None},
#  {'reviewId': 'b0e5b4bd-c7fa-4138-a605-69b019d9d25d',
#   'userName': 'maduraiss association',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSiCOtAADAfsGUl7KQRNjOWUChW-PSMDzl8ICmdBNUgSFnu',
#   'content': 'Very bad experience',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.1',
#   'at': datetime.datetime(2023, 8, 21, 15, 46, 58),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 8, 22, 5, 16, 39),
#   'appVersion': '2.3.1'},
#  {'reviewId': '24724dd8-37c5-4a56-82a2-f38ffd47ed5e',
#   'userName': 'UK07 pupg lover Raj PaNwAr',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSsmq39kJbx0MVSecgPdFBMVCOxRuHkwYr6TzB2BfzJUMk',
#   'content': 'Nic working apps',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.3.0',
#   'at': datetime.datetime(2023, 8, 21, 12, 54, 45),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 22, 5, 16, 28),
#   'appVersion': '2.3.0'},
#  {'reviewId': '0a4a1688-4769-4f9e-b5da-cbd0ac6484b4',
#   'userName': 'Darian Kobe',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfCThsh0utDnirKHYB2WE7-38WOTMvSQOp7phJtNyDK=mo',
#   'content': 'Excellent',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 8, 21, 11, 55, 38),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 8, 22, 5, 16, 22),
#   'appVersion': None},
#  {'reviewId': 'b0e24e2d-16af-4e9f-91e3-39789fcb7f64',
#   'userName': 'Faruk Mallick (BWN0368102F)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTKSt2jtt-eLLadVyg5lN1wERN6Hu10PyXLioxkm6b5AVI',
#   'content': 'Account closure option does not work during emergency.If you contact the customer care about the problem, the customer care asks you to go to the bank.If banking is to do all the work offline then there is no need for this application.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 8, 21, 11, 47, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '34405789-daef-4948-965f-dbdc4af47c12',
#   'userName': 'PIYUSH SINGWARIYA',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMR60o5GOECHCH8ivismryVo_H5j3NYa_rphwulZ9wciSlQ',
#   'content': 'Needs to dowload statement and payment slip option from mbandhan app.There is no option for download statement and payment slip.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 8, 21, 11, 41, 20),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2022, 11, 17, 6, 50, 13),
#   'appVersion': None},
#  {'reviewId': 'cb6ac54e-6971-4872-81ca-278137f714d3',
#   'userName': 'deepak kumar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQFVpbMYM6T94SOLMdPJMFCJEFzfssbFigz_sweyyTWJA',
# ...
#   'at': datetime.datetime(2023, 1, 31, 8, 31, 49),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 43, 5),
#   'appVersion': '2.2.8'},
#  {'reviewId': '28273371-2965-44e1-8aaf-a26faeb9d534',
#   'userName': 'Rahul Dharajiya',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQJZKaAnkHnZMmFi3aYFudkx5Wj6bQjbtYnvmgoR5JsEAU',
#   'content': 'My home loan not show in bandhanbank',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 1, 31, 7, 40, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '662465ef-915c-4357-85f2-e8d2e5956772',
#   'userName': 'Gautam Mukherjee',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRO5h7W_se0sVNduYa_0zIzPAwcxkvew6G1DD8dl8rRuIA',
#   'content': 'Satisfactory',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 31, 5, 47, 28),
#   'replyContent': 'Thank you for reviewing us.',
#   'repliedAt': datetime.datetime(2023, 2, 1, 12, 8, 56),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'ac80b854-645a-4b92-b406-b35e002dc79d',
#   'userName': 'Abdul Ajij',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfCbyjyrQqBkXu8FF5z8haBwpJFRjCQ3uqcjfUDdamv=mo',
#   'content': 'W aya only one one one onewqwwwwwqwyay ay Z is the only onlyy onlyyWWW',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 31, 5, 21, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.2.8'},
#  {'reviewId': '4c5b58dd-cfe0-41dc-90c5-83f407bde139',
#   'userName': 'HARIHARRAO KAPEERU',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRcwN5jIQ16S20ICcvSZEmTc-NIVIuY0Yl0FMN4bH1d4o8',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 30, 17, 30, 57),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 2, 1, 12, 8, 15),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'dca75bd8-24ac-4402-9a6c-f9103fffc093',
#   'userName': 'Istiyak Ahumed',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRSSlMftqFXl306EdAG8CoDIwsmD6pYk43iPESDpLTXUro',
#   'content': 'Faltu aap ha totally sar dard',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 30, 16, 6, 45),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 2, 1, 12, 8, 8),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'a23f9dc8-160b-44e2-b5d7-105e98e2792e',
#   'userName': 'Vaibhav Mittal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcLuU2Vg4XGgU0Dis9nBhSOQ0K-wPfJ1LsS1DeP1Iy9=mo',
#   'content': 'Very bad app I m not able to register after 10 times of trying',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 30, 14, 38),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 43, 23),
#   'appVersion': '2.2.8'},
#  {'reviewId': '2aceb973-1fc9-46bc-a022-012aff0dafaa',
#   'userName': 'Subhrajit Patra',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSyd6nX-qt0h80pOQp6cteh5JCklbVyW-Yfi-Ij-B-6wTDI',
#   'content': 'Useless, Slow, Buggy app.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 30, 12, 5, 31),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 43, 28),
#   'appVersion': '2.2.8'},
#  {'reviewId': '6a49ff3e-3cfe-45bc-8832-fd9bf8abca5a',
#   'userName': 'sandip gorai',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTHZ8zMd3sco3CCyDAjPl79sPaA-DczAnCDapABP1UFLsc',
#   'content': 'Ok',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 30, 12, 2, 5),
#   'replyContent': 'Thank you for reviewing us.',
#   'repliedAt': datetime.datetime(2023, 2, 1, 12, 7, 59),
#   'appVersion': '2.2.8'},
#  {'reviewId': '25e46091-13e0-491d-af50-446086608435',
#   'userName': 'Zayed Hazari',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRytcZh9T0Dm1Z2zbAWfwcwC3dxd0_F0Z08o0m8CvJIMPI',
#   'content': 'From more than a year or so the app is damn slow Please rectify as early as possible',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 30, 5, 49, 55),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team. For further queries, request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com.',
#   'repliedAt': datetime.datetime(2023, 2, 1, 12, 7, 52),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'cc8ef0cf-b286-438a-bfa1-b7223c866ae7',
#   'userName': 'Tanuj Bakliwal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcgEQrehOtdFKTJ4ud5mC3PmiMxc_uoxwEDQAp-mywv=mo',
#   'content': 'Sar Bandhan Mein Mere ko account kholna hai',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 1, 29, 17, 23, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '169ed050-bc1b-4d03-a5cb-7a70fe6b873f',
#   'userName': 'MD TAHIDUL SHAIKH',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTk1mNsWnWb7MgtbzwZ7YzjlrOEPws5rnZEjBUTnIgHEYE',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 28, 11, 30, 21),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 2, 1, 12, 7, 9),
#   'appVersion': '2.2.8'},
#  {'reviewId': '0a281b70-1703-4bfa-a533-dd07a7b04531',
#   'userName': 'Suman Ghosh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte-QF5OxMcTIx94DMXT964wO5yAdZoaUAluQSMOR052=mo',
#   'content': 'not properly worked sometime...not worked on nothing phone 1 device...solve the issue immediately.',
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 28, 7, 51, 59),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 2, 1, 12, 7),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'b2e016be-a7ca-40eb-810d-eae7d6d6e987',
#   'userName': 'Megha Bansal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQRAg-cqKaUTVSGvc4BCtIClbjABq-h1S-fGxcm12vyqCk',
#   'content': 'Very bad app so nuch lagging I am just frustrated alot disgusting app',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 28, 5, 57),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 42, 38),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'a89dcb55-9e41-4969-a79d-762075fb9249',
#   'userName': 'jiten sarkar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSr4GgzDvk23ZL535XJRiJRGg5KZX-m4h0DAi1MZro392I',
#   'content': 'Very slow',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 28, 0, 53, 22),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 42, 35),
#   'appVersion': '2.2.8'},
#  {'reviewId': '8c21ea6d-9569-4b66-a072-f506fcd78af3',
#   'userName': 'Dilip Singha',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdBilZv1ld5wwLAI4m6Lrq881wMb7XqZRRQivxyDX8S=mo',
#   'content': "World most last class bank don't open account",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 1, 27, 16, 1, 57),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 42, 28),
#   'appVersion': None},
#  {'reviewId': '33def81f-3cba-40f5-8fbb-7217992f3e58',
#   'userName': 'sony singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQ9yrErN_JicUTPCBGcE4Gnyb2LZtv6Vo0AEPUrsZCRFeo',
#   'content': 'Worst',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 27, 7, 53, 35),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 42, 25),
#   'appVersion': '2.2.8'},
#  {'reviewId': '8c2817e1-0134-48d7-a99f-e7dfc7dce131',
#   'userName': 'Md Israr Alam',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMR6p4eBzvOGLIZg_D4r5UT3pRk08lWItQTmTULEL-iI9zWA',
#   'content': 'Very very slow working',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 27, 7, 32, 27),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 42, 16),
#   'appVersion': '2.2.8'},
#  {'reviewId': '842575db-13c3-4966-a6e6-f9a76436cd01',
#   'userName': 'Slok Gupta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTVEiongBNQT5g8GbEtKYGXH9CibKDYWK1oDy02UN1gxiLm',
#   'content': "App doesn't work and is very frustrating",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 27, 6, 53, 19),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 42, 7),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'fa16ec62-b361-481d-9c88-3ba0aa6614cb',
#   'userName': 'Arif Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSwZ2NbiEZ9L68TSuLWDKo0ewcNUPThUlKtHlGyJBBSxQ',
#   'content': 'Varriy bad',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 27, 1, 6, 6),
#   'replyContent': 'Sincere apologies for the inconvenience caused. To help us understand your issue better, we request you to call us on our toll-free number 1800-258-8181 or write to us at customercare@bandhanbank.com. You may also visit https://bit.ly/3yGjUYU for further process.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 42, 2),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'bc3e486a-2736-4dfc-b058-c1a30745fdbf',
#   'userName': 'Sooraj Hembram',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMR9wl7tfzH9T6KQm1WT44AlxyobJYLa1FxpeTMAD3MHv5A',
#   'content': 'Difficulty to log in',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 1, 26, 13, 29, 16),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 41, 31),
#   'appVersion': None},
#  {'reviewId': 'e58814df-33af-4b6f-9de4-36e9ed1695d0',
#   'userName': 'Alamin Raj (Raj)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTwkccNVgxcyAHFNFu-YQRVUZDpHRsn2xcvy2bhsIeEFA',
#   'content': 'So good and suppar in this cantry',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 1, 26, 12, 36, 48),
#   'replyContent': 'Thank you for your positive review. We hope you continue to experience convenient banking with mBandhan mobile app.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 41, 42),
#   'appVersion': None},
#  {'reviewId': '6b5d1412-1360-489c-8395-5ed4b676ca0d',
#   'userName': 'rajjak sk',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT6zrqX75_HYGtuqg_Sj0kQuaqsllAYF40Fs38vOsEJpRU',
#   'content': 'RAJJAKsk',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 25, 16, 59, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.2.8'},
#  {'reviewId': '9030a0da-277c-4a65-9ab7-3ff751f5349e',
#   'userName': 'pradeep vishwakarma',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTHB3PhDqSW-_6L-2fTIGowpQHS3gDMeGEhP6aKToo3TtI',
#   'content': "Very worst application I'm didn't see that type application in my life I'm also using other bank application and net banking n all but bandhan bank not providing proper service application was very slow also unable to do transactions from upi also nit getting proper support from customers care and from bank employee.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 25, 15, 0, 33),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 41, 27),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'd06b5c42-e430-40d9-a460-9f6db5f84532',
#   'userName': 'Narsingh Bhai',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfs98U7NoW-jBzG3yo0a7Va5fbQcF1Ri2G69-89W5fy=mo',
#   'content': 'slowly working also provide screen shot fecility',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 25, 14, 25, 44),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 41, 19),
#   'appVersion': '2.2.8'},
#  {'reviewId': 'fa68f61a-35db-4987-bc79-fb4ce0613e91',
#   'userName': 'somnath chatterjee',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQETGsL_IVJyDHpIU0THtaBz-oL_VWf9seK9HiwcNbtBw',
#   'content': 'One of the most 3rd class banks . Most of the time the server remains down. Since this is a corporate account cannot stop also. The app is also a 3rd grade, not at all user friendly.',
#   'score': 3,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 25, 11, 35, 4),
#   'replyContent': 'Sincere apologies for the inconvenience caused. We have noted your issue and have shared it with our concerned team.',
#   'repliedAt': datetime.datetime(2023, 1, 31, 12, 41, 15),
#   'appVersion': '2.2.8'},
#  {'reviewId': '0137cf35-5792-4c4c-948d-bccf5f0242d8',
#   'userName': 'Rajesh Jaiswani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRFJeVAnuai2fgBAeXXrC6Z0Lnh86Tbf8EJ-seSzazrvco',
#   'content': 'Worst banking app 0 star for no improvement',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.2.8',
#   'at': datetime.datetime(2023, 1, 25, 10, 4, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.2.8'},
#  ...]

# %%
df = pd.DataFrame(np.array(ind_reviews),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df.head()
# Out:
#                                reviewId             userName  \
# 0  99a53d43-09cc-4690-8b3c-cfe2502cb205  Kirtizala Zalakirti
# 1  ec0ad500-4430-4c42-9900-6541851915dc     sudhakar chandha
# 2  e6d945dc-262d-4a86-a18e-591250c5f22d    Biswajit Mazumdar
# 3  92d60372-9ff4-44bb-bc9d-6f67969b8244    ronit kumar Singh
# 4  485139fa-bd1a-46d4-bc50-d8fb4422d0fb          Trinath Ray
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AAcHTt...
# 1  https://play-lh.googleusercontent.com/a/AAcHTt...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0                                     Zala KIRTISINH      5              0
# 1                                               Good      5              0
# 2  please upgrade your 3rd class app, Better than...      1              0
# 3  The mobile application UI is pathetic and it l...      1              0
# 4  Very disappointing experience. Need be complet...      1              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                 None 2023-09-06 02:29:26         None       NaT       None
# 1                2.3.1 2023-09-05 17:25:45         None       NaT      2.3.1
# 2                 None 2023-09-05 17:05:05         None       NaT       None
# 3                2.3.1 2023-09-05 17:03:12         None       NaT      2.3.1
# 4                2.3.1 2023-09-05 16:41:02         None       NaT      2.3.1

# %%
df['score'].mean()
# Out:
# 3.2741445163301894

# %%
df['score'].value_counts()
# Out:
# 5    5934
# 1    4372
# 4    1087
# 3     742
# 2     694
# Name: score, dtype: int64

# %%
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
with open('/gdrive/My Drive/Colab Notebooks/mbandhan.csv', 'w') as f:
  df.to_csv(f)
