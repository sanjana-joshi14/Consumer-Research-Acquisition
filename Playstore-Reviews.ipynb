# %%
pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import app, Sort, reviews_all


ind_reviews = reviews_all(
    'app_name',
    sleep_milliseconds=0,
    lang='en',
    country='in',
    sort=Sort.NEWEST,
    filter_score_with=None
)

# %%
ind_reviews
# Out:
# [{'reviewId': 'aa602ed6-71a1-4a5b-acfd-4504900308b9',
#   'userName': 'Suneel Kuma',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucqSxHXXozOijYNYUxAzXBUSmP7aB4eoS6CCaz-X',
#   'content': 'Good',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 8, 25, 10, 26, 27),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'fb97ac55-7957-4031-811f-c453457c5a13',
#   'userName': 'Aamir Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucozuxYiFRUHwEmas2B_PM19tFqjWPBFrRGpD3N5bg',
#   'content': "I don't think products available over this application are original. Possibility of getting scam is there.",
#   'score': 1,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '3.4',
#   'at': datetime.datetime(2022, 7, 3, 12, 14, 2),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '108d8c91-51aa-48cc-af43-c09f96d939e4',
#   'userName': 'Rupam Singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucoM2SC9cogfcmDE4NVkh3icTRI4PeN-GR2SYD_A',
#   'content': 'Excellent',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 5, 26, 3, 36, 32),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'd319f608-4a08-494f-8be9-deac02365d86',
#   'userName': 'ranjan bhaiji Patariya',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucpF0VJU4XPWNCS6engTl0NnZ8-jkRCzNbi8hE4k',
#   'content': "Big scammers.....don't buy anything from them",
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '3.3',
#   'at': datetime.datetime(2022, 1, 28, 18, 3, 59),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '126df0bb-e2da-42a1-a148-7f251746245a',
#   'userName': 'udit batra',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZuco8UafcaoZO9Os-ny8QRaBc5Qxe3cCpgjSgwXXAdw',
#   'content': 'These guys have no idea what they are doing , they trying to sell luxuary products but even after 3 days making payment them are not able to confirm me wether they have received it or not . *Customer care team is so arrogant that you wont be able to stand them . PLS RATHER USE TATA LUX , THEY KNOW SERVICE IS PART OF LUXUARY.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.5',
#   'at': datetime.datetime(2021, 8, 16, 9, 26, 36),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '17b16dc3-0e4f-40da-907b-7c810dd0a2c9',
#   'userName': 'NITHIN Youtube',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmlcvvl1Q5lmx1aQZ6G17Qo_DiUcITfWbqj4kC5i=mo',
#   'content': 'Goodone',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 7, 17, 11, 5, 44),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'd42b4bab-47de-4de4-8ab8-29c67baefcfa',
#   'userName': 'Nikitha Gandhi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucrcsK74uWidSkLxMjrdNM7zZVR4ZXKyjodFxc7eNw',
#   'content': 'Its bs',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 6, 6, 13, 15, 2),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'f4375cee-376e-41e8-8b3a-a2601f9824f6',
#   'userName': 'Abhidnya Ukalkar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucpkvTCPYzcVwczaNOv5PBOXfNhNqJ4NqgU88O4gpU4',
#   'content': 'User experience in the app is extremely poor. They really need to work on making the customer experience on the app good if the products they sell are luxury items. I would rather go and buy luxury in store than online if the experience is going to be this bad.',
#   'score': 1,
#   'thumbsUpCount': 28,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 5, 30, 7, 10, 21),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'ce227584-9198-4592-a990-4bf5c331d9a9',
#   'userName': 'Ghanshyam Patel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmlAi-bfX3BYEwmBal8pwoE6oSRVBLGZS0qXYpRa=mo',
#   'content': 'Nice',
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.4',
#   'at': datetime.datetime(2021, 3, 12, 12, 9, 34),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '8a36ad09-35af-48fd-b990-454e0fed9a69',
#   'userName': 'Alankar Devta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucrfxEUeAEfky_UDhmq9xZaiZ7S-07bGUIPrwBiM',
#   'content': "There are some serious issues with this app. I tried to open my wishlist, but it's taking forever, even after uninstalling and reinstalling the app again. Please fix this.",
#   'score': 1,
#   'thumbsUpCount': 37,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 2, 18, 6, 5, 51),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '1c5e4112-b94c-444d-9e88-6f89b83849c4',
#   'userName': 'TANYA KHANDELWAL',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucqbGq_jV7wXvNtbEEYQQ8nf3MRcMwhk4xai1bFPJJg',
#   'content': 'Very bad very few details about goods are given',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 9, 16, 11, 29, 4),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'b9c04d9f-3a87-4831-8937-cae16ed23c63',
#   'userName': 'Anju Shrivastava',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZuco1Vw8pWveSuZDCzBt4c0rYJlshXWMUwWK-pZBdiw',
#   'content': 'Good experience with this app',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2020, 5, 23, 16, 39, 14),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'fc4d5444-42fc-4a8a-8676-344dabd5d356',
#   'userName': 'Noori Khan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucoMpFd58FEv-gflCbXaMrFGkOzfQGoiT51oFBjPSw',
#   'content': 'Amazing collection highly recommended for everyone.',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 5, 23, 8, 14, 36),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '72258b69-83c3-4309-8d7b-e3b09abf8692',
#   'userName': 'Deepak Parashar',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmk7XIdwoQKuMpt6SbnOeVvIOGzblJsYCnq8NJ3DXA=mo',
#   'content': 'Awesome collection',
#   'score': 5,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 5, 22, 13, 58, 13),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '48df0f20-6769-4444-bc5c-93d8ba167792',
#   'userName': 'RISHI SHRESTHA FITNESS',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucrK7t6wT0AGQ4KOSJq7_dxcieHZ11q7TalhC2VnJD8',
#   'content': 'Extremely fantastic app for luxury shopping this is largest market place for luxury shopping an adorable price',
#   'score': 5,
#   'thumbsUpCount': 13,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2020, 5, 22, 12, 34, 50),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'eb847b56-af68-4abf-ab97-6ad3a6d0b4b2',
#   'userName': 'sunil mehra',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmmqE0xJIQvuoqsn-7EJ3p9e5ML6MXuKXlvHk3XR=mo',
#   'content': 'Amazing collection',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 5, 22, 12, 10, 4),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '9c9d4245-34ed-4f0e-a452-43634bd18171',
#   'userName': 'Dinesh Gupta',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmlCYlox7hg9MLO5kVAt7IsQF2Ppnj6C6UQtDSaL=mo',
#   'content': 'Lowest price. Good quality of product',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 5, 22, 12, 6, 10),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '400c00bf-4240-4a46-836b-03686bba4cc2',
#   'userName': 'Rampal Mehra',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmmQ6rSZ1wSUjmiQVSv9EWVzPGWvkDYgdKm0aVam=mo',
#   'content': 'amazing price amazing aap',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 5, 22, 12, 0, 10),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '28280967-171d-4c45-97ea-c6d2a5b0eff4',
#   'userName': 'Rachna Mattoo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucoIfJ26zwZnt9vdSelG8alJC3oiI-76oGvX30UFnQ',
#   'content': 'Good collection of luxury products. User friendly app. 👍',
#   'score': 5,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2020, 5, 22, 11, 41, 42),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '323fb752-c88d-4d44-a0dc-26e93d292635',
#   'userName': 'Varushi Sharma',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmkYJtgcMvI09VLeD4_DRdsrj38SAPhxF-tctAU4=mo',
#   'content': 'Great app for experiencing your favorite luxury brands. It is fast and super easy to use.',
#   'score': 5,
#   'thumbsUpCount': 42,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 5, 22, 11, 25, 33),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '8b42e07d-d37d-42d2-8fdd-7e5d5c88f9ca',
#   'userName': 'Prem Lata',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucrQdhUCN8-6ncFMHlOJ9ArOQBigAfu3Qz_4bIzX',
#   'content': 'Love the app. It is quite user friendly and easy to use.',
#   'score': 5,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 5, 22, 11, 21, 3),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'd76e6e47-6bd0-4f65-9094-b01941d57828',
#   'userName': 'Sitaram Aman india',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucrrkgPwXyvamF9eSwfLs8pqTlnkpfZRb3lxfbthtMU',
#   'content': 'Amazing collection, love it!',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2020, 5, 22, 11, 15, 9),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '19041e3e-a9e3-4838-93f0-ba2dcdc22104',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Its just waste of time this app is master in clickbate worst',
#   'score': 1,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2020, 4, 2, 16, 37, 3),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '8d4f678e-0fb7-46c1-a455-98421b4f2991',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "Price low to high isn't working . Cheating baj app.",
#   'score': 1,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2020, 3, 31, 13, 15, 38),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'c820d2e2-2d0c-43a0-b6e3-03fdb2e1bae3',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'I think there is no valid price for each and every product .... one can buy a silk sarree ....instead of buying a simple top in this app ...💔waste of maney. ....',
#   'score': 1,
#   'thumbsUpCount': 13,
#   'reviewCreatedVersion': '1.2.1',
#   'at': datetime.datetime(2020, 2, 11, 1, 18, 51),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '4230577f-fd88-472b-ad34-3e3f5e67bf5e',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "This app doesn't work. Nothing opens up whatever you click. Its just a static fancy looking thing.",
#   'score': 1,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 1, 22, 17, 1, 15),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '7ebfde38-50ad-40fa-97f5-0d3307b55dcb',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Excellent app for luxury goods',
#   'score': 4,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.2',
#   'at': datetime.datetime(2019, 12, 11, 1, 36, 57),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '3bb89188-3365-4423-a91a-a94f8cad45bd',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "App doesn't work",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.2',
#   'at': datetime.datetime(2019, 12, 10, 13, 44, 33),
#   'replyContent': None,
#   'repliedAt': None}]

# %%
df = pd.DataFrame(np.array(ind_reviews),columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df.head()
# Out:
#                                reviewId                userName  \
# 0  aa602ed6-71a1-4a5b-acfd-4504900308b9             Suneel Kuma
# 1  fb97ac55-7957-4031-811f-c453457c5a13              Aamir Khan
# 2  108d8c91-51aa-48cc-af43-c09f96d939e4             Rupam Singh
# 3  d319f608-4a08-494f-8be9-deac02365d86  ranjan bhaiji Patariya
# 4  126df0bb-e2da-42a1-a148-7f251746245a              udit batra
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AFdZu...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a-/AFdZu...
#
#                                              content  score  thumbsUpCount  \
# 0                                               Good      1              0
# 1  I don't think products available over this app...      1              6
# 2                                          Excellent      5              1
# 3      Big scammers.....don't buy anything from them      1              2
# 4  These guys have no idea what they are doing , ...      1              1
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0                 None 2022-08-25 10:26:27         None      None
# 1                  3.4 2022-07-03 12:14:02         None      None
# 2                 None 2022-05-26 03:36:32         None      None
# 3                  3.3 2022-01-28 18:03:59         None      None
# 4                  2.5 2021-08-16 09:26:36         None      None

# %%
df['score'].mean()
# Out:
# 3.2142857142857144

# %%
df['score'].value_counts()
# Out:
# 5    14
# 1    12
# 4     2
# Name: score, dtype: int64

# %%
from google.colab import drive

# %%
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
with open('/gdrive/My Drive/Colab Notebooks/data.csv', 'w') as f:
  df.to_csv(f)
